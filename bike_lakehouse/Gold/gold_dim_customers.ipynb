# %% [markdown]
# # Transformation Logic

# %%
query = """
SELECT
    ROW_NUMBER() OVER (ORDER BY ci.customer_id) AS customer_key,
    ci.customer_id,
    ci.customer_number,
    ci.first_name,
    ci.last_name,
    la.country,
    ci.marital_status,
    CASE
        WHEN ci.gender <> 'n/a' THEN ci.gender
        ELSE COALESCE(ca.gender, 'n/a')
    END AS gender,
    ca.birth_date AS birthdate,
    ci.created_date AS create_date
FROM de_project.silver.crm_customers ci
LEFT JOIN de_project.silver.erp_customers ca
    ON ci.customer_number = ca.customer_number
LEFT JOIN de_project.silver.erp_customer_location la
    ON ci.customer_number = la.customer_number
"""
df = spark.sql(query)

# %% [markdown]
# # Writing Gold Table

# %%
df.write.mode("overwrite").format("delta").saveAsTable("de_project.gold.dim_customers")

# %%
# %sql
SELECT * FROM de_project.gold.dim_customers LIMIT 10
